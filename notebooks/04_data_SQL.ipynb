# %%
import sqlite3
import pandas as pd

# %%
df_content_clean = pd.read_csv("..\data\cleaned\steam_content_clean.csv")

conn = sqlite3.connect('..\database\steam_games.db')

df_content_clean.to_sql('content_support', conn, if_exists='replace', index=False)

print("table loaded")

conn.close()
# Out:
# table loaded

# %%
conn = sqlite3.connect('..\database\steam_games.db')

query = '''
Select a.app_id,
a.latest_date,
a.tags,
b.is_free,
b.dlc_count


FROM content_support a 
LEFT JOIN games_metadata b on a.app_id = b.app_id
WHERE a.tags = "patchnotes" AND b.genres LIKE '%RPG%'

'''
print(pd.read_sql(query, conn))
# Out:
#      app_id          latest_date        tags  is_free  dlc_count
# 0    108600  2026-04-08 09:49:00  patchnotes        0          0
# 1    218620  2026-04-05 10:39:39  patchnotes        0         81
# 2    238960  2026-03-24 16:39:40  patchnotes        1          6
# 3    247080  2023-08-29 17:43:17  patchnotes        0         14
# 4    251570  2026-03-20 21:32:59  patchnotes        0          9
# ..      ...                  ...         ...      ...        ...
# 61  2186680  2025-12-16 04:08:15  patchnotes        0          9
# 62  2322010  2025-08-20 11:39:05  patchnotes        0          3
# 63  2349820  2026-04-29 17:29:34  patchnotes        1          0
# 64  2457220  2026-03-25 13:12:01  patchnotes        0          2
# 65  2646460  2026-04-29 03:02:31  patchnotes        0          4
#
# [66 rows x 5 columns]
