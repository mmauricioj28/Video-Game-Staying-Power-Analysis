# %%
import pandas as pd

# %%
df_check = pd.read_csv("../data/raw/steam_metadata_batch1.csv")
df_check.head()
# Out:
#    app_id                       name  type  is_free  release_date  \
# 0     730           Counter-Strike 2  game     True  21 Aug, 2012
# 1     570                     Dota 2  game     True   Jul 9, 2013
# 2     440            Team Fortress 2  game     True  Oct 10, 2007
# 3  578080        PUBG: BATTLEGROUNDS  game     True  Dec 21, 2017
# 4  271590  Grand Theft Auto V Legacy  game    False  Apr 13, 2015
#
#    coming_soon  price_usd        developers      publishers  \
# 0        False        0.0             Valve           Valve
# 1        False        0.0             Valve           Valve
# 2        False        0.0             Valve           Valve
# 3        False        0.0  PUBG Corporation   KRAFTON, Inc.
# 4        False        NaN    Rockstar North  Rockstar Games
#
#                                               genres  \
# 0                               Action, Free To Play
# 1                     Action, Strategy, Free To Play
# 2                               Action, Free To Play
# 3  Action, Adventure, Massively Multiplayer, Free...
# 4                                  Action, Adventure
#
#                                           categories  dlc_count  required_age  \
# 0  Multi-player, Cross-Platform Multiplayer, Stea...          1             0
# 1  Multi-player, Co-op, Steam Trading Cards, Stea...          2             0
# 2  Multi-player, Cross-Platform Multiplayer, Stea...          1             0
# 3  Multi-player, PvP, Online PvP, Custom Volume C...          0            13
# 4  Single-player, Multi-player, PvP, Online PvP, ...          0            17
#
#                                         header_image  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                             website
# 0        http://counter-strike.net/
# 1             http://www.dota2.com/
# 2      http://www.teamfortress.com/
# 3              https://www.pubg.com
# 4  https://www.rockstargames.com/V/

# %%
print(df_check.info())
print(df_check.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   app_id        20 non-null     int64
#  1   name          20 non-null     object
#  2   type          20 non-null     object
#  3   is_free       20 non-null     bool
#  4   release_date  20 non-null     object
#  5   coming_soon   20 non-null     bool
#  6   price_usd     18 non-null     float64
#  7   developers    20 non-null     object
#  8   publishers    20 non-null     object
#  9   genres        20 non-null     object
#  10  categories    20 non-null     object
#  11  dlc_count     20 non-null     int64
#  12  required_age  20 non-null     int64
#  13  header_image  20 non-null     object
#  14  website       19 non-null     object
# dtypes: bool(2), float64(1), int64(3), object(9)
# memory usage: 2.2+ KB
# None
# app_id          0
# name            0
# type            0
# is_free         0
# release_date    0
# coming_soon     0
# price_usd       2
# developers      0
# publishers      0
# genres          0
# categories      0
# dlc_count       0
# required_age    0
# header_image    0
# website         1
# dtype: int64

# %%
df_check.columns = df_check.columns.str.strip().str.lower()

df_check["release_date"] = pd.to_datetime(df_check["release_date"], errors="coerce")

df_check = df_check.drop_duplicates(subset="app_id")
print(df_check.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   app_id        20 non-null     int64
#  1   name          20 non-null     object
#  2   type          20 non-null     object
#  3   is_free       20 non-null     bool
#  4   release_date  5 non-null      datetime64[ns]
#  5   coming_soon   20 non-null     bool
#  6   price_usd     18 non-null     float64
#  7   developers    20 non-null     object
#  8   publishers    20 non-null     object
#  9   genres        20 non-null     object
#  10  categories    20 non-null     object
#  11  dlc_count     20 non-null     int64
#  12  required_age  20 non-null     int64
#  13  header_image  20 non-null     object
#  14  website       19 non-null     object
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(3), object(8)
# memory usage: 2.2+ KB
# None

# %%
df_released_games = df_check[df_check['coming_soon'] == False]
df_released_games = df_released_games.drop(columns = ['coming_soon'])

# %%
import os
os.makedirs("../data/cleaned", exist_ok=True)

df_released_games.to_csv("../data/cleaned/steam_metadata_released_clean.csv", index=False)
df_check.to_csv("../data/cleaned/steam_metadata_all_clean.csv")
print("Cleaned file saved.")
# Out:
# Cleaned file saved.
